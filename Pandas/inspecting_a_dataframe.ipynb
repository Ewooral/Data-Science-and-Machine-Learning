# %%
import pandas as pd
# INSPECTING A DATAFRAME

# print the homelessness csv datafrane
newDF = pd.read_csv("homelessness.csv")

# delete the Unnamed: 0 column
homelessness = newDF.drop('Unnamed: 0', axis=1)
print(homelessness)

# save changes to a new csv file called newHome.csv
homelessness.to_csv("newHome.csv")
print("........................................................................")


print(newDF)

print("......................................................................")

# Print the head of the homelessness data
print(homelessness.head())


print("......................................................................")
# Print information about homelessness
print(homelessness.info())


print("......................................................................")
# Print the shape of homelessness
print(homelessness.shape)


print("......................................................................")
# Print a description of homelessness
print(homelessness.describe())
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama       2570.0           864.0
# 1              Pacific                Alaska       1434.0           582.0
# 2             Mountain               Arizona       7259.0          2606.0
# 3   West South Central              Arkansas       2280.0           432.0
# 4              Pacific            California     109008.0         20964.0
# 5             Mountain              Colorado       7607.0          3250.0
# 6          New England           Connecticut       2280.0          1696.0
# 7       South Atlantic              Delaware        708.0           374.0
# 8       South Atlantic  District of Columbia       3770.0          3134.0
# 9       South Atlantic               Florida      21443.0          9587.0
# 10      South Atlantic               Georgia       6943.0          2556.0
# 11             Pacific                Hawaii       4131.0          2399.0
# ...

# %%
# Print the values of homelessness
# print(homelessness.values)

print("......................................................................")
# Print the column index of homelessness
print("Columns: ", homelessness.columns)

print("......................................................................")
# Print the row index of homelessness
print("Index: ", homelessness.index)

# sort the family_members column of our dataframe
homelessness.sort_values('family_members')

print(homelessness.head())
# Out:
# ......................................................................
# Columns:  Index(['region', 'state', 'individuals', 'family_members', 'state_pop'], dtype='object')
# ......................................................................
# Index:  RangeIndex(start=0, stop=51, step=1)
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588

# %%
# Changing the index of the dataframe to start from 10 -> len(homelessness.index) + 1 instead of 0 - len(homelessness.index)

nums = [i for i in range(10, len(homelessness.index) + 10)]
# print(nums)

homelessness.index = nums
print(homelessness.index  < 30)

print(homelessness['individuals']  > 10000)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False]
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53     True
# 54    False
# 55    False
# 56    False
# 57     True
# ...
