# %% [markdown]
# # LINEAR REGRESSION
# ### First Machine Learning Algorithm

# %% [markdown]
# It is used to model a phenomenon or made predictions or discover hidden patterns among things.
# Imagine that you're a film producer, you provide money to make movies, and when the movies make money
# you make money, and when the movies loose money, you loose money.
#
# You just invested huge sums of money on a movie called Zombies rise again. Now you're worried
# whether your money is gone, or you'll go bankrupt, or your movie won't sell or do well.
#
# To answer the above concerns, you should be able to predict the future and this is where data science
# will come to the rescue.
#
# ### How a data scientist will approach the problem
# * formulate clear Question
# * Gather Data
# * Clean Data(missing or incomplete data, errors, bad formatting)
# * Expore and Visualize
# * Train the Algorithm(Linear Regression, use our computer to identify hidden patterns)
# * Evaluate( how did the algorithm do, was it accurate, did it solve our problem?)
#
# ### 1. Formulate the Question
# * How much revenue will our movie make?
# * Can we use movie budgets to predict movie revenue?
#
# ### 2. Gather Data
# * Data on feature(Budget)
# * Data on target(Revenue)
#
# ### 3. Clean Data
# * delete all unreleased movie columns
# * delete all other columns except, worldwide gross and production budget
#
# ### 4. Explore and Visualize
# * using pandas and matplotlib, we can visualize our data

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Files/03.2 cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x = DataFrame(data, columns=['production_budget_usd'])
y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.3)
plt.title('Films Cost vrs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# ### 5. Train the Algorithm - Linear Regression
# * slope = change in y / change in x
# * equation of a line: y = mx + c
#                     h0(x) = 0o + 01x
#
# * point on a line is called `Fitted Value/predicted value`
# * wide line between data point values and point on a line is called `Residuals`
#
# Residuals =  Actual values - predicted values

# %%
regression = LinearRegression()
regression.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# * Slope Coefficient:

# %%
regression.coef_
# Out:
# array([[3.11150918]])

# %% [markdown]
# * Intercept
# This means a movie with a budget of zero will lose over 7 million dollars

# %%
regression.intercept_
# Out:
# array([-7236192.72913963])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.3)
plt.plot(x, regression.predict(x), color='red', linewidth=4)
plt.title('Films Cost vrs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# * Goodness of fit
# this is the amount of variation in films revenue that is explained by the film budget

# %%
regression.score(x, y)
# Out:
# 0.5496485356985727
